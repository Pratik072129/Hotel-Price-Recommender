# %%
# prompt: 'Spectral': SpectralClustering find accuracy in hotel_data.csv

from sklearn.cluster import SpectralClustering

# Initialize and train a Spectral Clustering model
spectral_clustering = SpectralClustering(n_clusters=3, assign_labels='kmeans', random_state=42) # Adjust n_clusters if needed
spectral_clustering.fit(X_train)

# Predict clusters for the test set
y_pred_spectral = spectral_clustering.fit_predict(X_test)

# Since Spectral Clustering is unsupervised, we can't directly calculate accuracy.
# We can map the predicted clusters to the actual price categories and then calculate accuracy.

# Create a mapping (you might need to adjust this based on your data)
cluster_mapping = {0: 'Low', 1: 'Medium', 2: 'High'} # Example mapping - adjust as needed
y_pred_spectral_mapped = [cluster_mapping[cluster] for cluster in y_pred_spectral]

# Calculate accuracy (approximation)
accuracy_spectral = accuracy_score(y_test, y_pred_spectral_mapped)
print(f"Accuracy (approximation for Spectral Clustering): {accuracy_spectral}")

# Plot confusion matrix for Spectral Clustering (mapped)
plot_confusion_matrix(y_test, y_pred_spectral_mapped, "Spectral Clustering Confusion Matrix (Mapped)")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Accuracy (approximation for Spectral Clustering): 0.345
